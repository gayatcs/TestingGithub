# %%
import pandas as pd
print("Hello, World!");      
print(17 // 4)
# Out:
# Hello, World!

# %%
name = "Alice"
age = 30
height = 1.65
is_student = True
print(f"Name:{name} , Age:{age} , Height:{height} , Is Student:{is_student}")
